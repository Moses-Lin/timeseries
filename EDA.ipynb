# %% [markdown]
# ## Importing necessary things

# %%
import os
import warnings
warnings.filterwarnings('ignore')
import math
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight') 
# %matplotlib inline

from collections import Counter
import datetime

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import cm

import statsmodels.api as sm
from numpy.random import normal, seed
from scipy.stats import norm
from statsmodels.tsa.arima_model import ARMA
from statsmodels.tsa.stattools import adfuller
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from statsmodels.tsa.arima_process import ArmaProcess
from statsmodels.tsa.arima_model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv('train.csv')
df
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 0          1  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 1          2  CA-2017-152156  08/11/2017  11/11/2017    Second Class
# 2          3  CA-2017-138688  12/06/2017  16/06/2017    Second Class
# 3          4  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# 4          5  US-2016-108966  11/10/2016  18/10/2016  Standard Class
# ...      ...             ...         ...         ...             ...
# 9795    9796  CA-2017-125920  21/05/2017  28/05/2017  Standard Class
# 9796    9797  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9797    9798  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9798    9799  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
# 9799    9800  CA-2016-128608  12/01/2016  17/01/2016  Standard Class
#
#      Customer ID     Customer Name    Segment        Country             City  \
# ...

# %% [markdown]
# ## Checking each column for more information about types

# %%
df['Ship Mode'].value_counts()
# Out:
# Standard Class    5859
# Second Class      1902
# First Class       1501
# Same Day           538
# Name: Ship Mode, dtype: int64

# %%
shipmode1 = len(df[df['Ship Mode'] == 'Standard Class'])
shipmode2 = len(df[df['Ship Mode'] == 'Second Class'])
shipmode3 = len(df[df['Ship Mode'] == 'First Class'])
shipmode4 = len(df[df['Ship Mode'] == 'Same Day'])
total = shipmode1 + shipmode2 + shipmode3 + shipmode4


plt.figure(figsize=(10,10))

xaxis = ['Standard Class', 'Second Class', 'First Class', 'Same Day']
yaxis = [shipmode1, shipmode2, shipmode3, shipmode4]
ax = sns.barplot(xaxis, yaxis)

plt.title('Distribution of Shipping Options.')
plt.ylabel('Count', fontsize = 20)
plt.xlabel('Shipping Type', fontsize = 20)


for p in ax.patches:
             ax.annotate("%.2f" % (p.get_height()*100/total)+'%', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=15, color='black', xytext=(0, 20),
                 textcoords='offset points')

# %%
df['City'].value_counts()
# Out:
# New York City    891
# Los Angeles      728
# Philadelphia     532
# San Francisco    500
# Seattle          426
#                 ...
# Montebello         1
# Romeoville         1
# Waukesha           1
# Champaign          1
# Ontario            1
# Name: City, Length: 529, dtype: int64

# %%
citycount = Counter(df['City'])
citycount.most_common(10)
# Out:
# [('New York City', 891),
#  ('Los Angeles', 728),
#  ('Philadelphia', 532),
#  ('San Francisco', 500),
#  ('Seattle', 426),
#  ('Houston', 374),
#  ('Chicago', 308),
#  ('Columbus', 221),
#  ('San Diego', 170),
#  ('Springfield', 161)]

# %%
yaxiscity = [val[1] for val in citycount.most_common(10)]
xaxiscity = [val[0] for val in citycount.most_common(10)]

plt.figure(figsize=(18, 14))
ax = sns.barplot(xaxiscity, yaxiscity)
plt.title('Top 10 Most Common Cities that order', fontsize = 25)
plt.ylabel('Frequency', fontsize = 20)
plt.xticks(rotation=45, fontsize = 15)

for p in ax.patches:
             ax.annotate("%.2f" % (p.get_height()*100/sum(yaxiscity))+'%', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=13, color='black', xytext=(0, 20),
                 textcoords='offset points')

# %%
df['Segment'].value_counts()
# Out:
# Consumer       5101
# Corporate      2953
# Home Office    1746
# Name: Segment, dtype: int64

# %%
df['State'].value_counts()
# Out:
# California              1946
# New York                1097
# Texas                    973
# Pennsylvania             582
# Washington               504
# Illinois                 483
# Ohio                     454
# Florida                  373
# Michigan                 253
# North Carolina           247
# Virginia                 224
# Arizona                  223
# Tennessee                183
# Colorado                 179
# Georgia                  177
# Kentucky                 137
# Massachusetts            135
# Indiana                  135
# New Jersey               122
# Oregon                   122
# Maryland                 105
# Wisconsin                105
# Delaware                  93
# Minnesota                 89
# Connecticut               82
# Missouri                  66
# Oklahoma                  66
# Alabama                   61
# Arkansas                  60
# Rhode Island              55
# Mississippi               53
# Utah                      53
# ...

# %%
df['Region'].value_counts()
# Out:
# West       3140
# East       2785
# Central    2277
# South      1598
# Name: Region, dtype: int64

# %%
df['Category'].value_counts()
# Out:
# Office Supplies    5909
# Furniture          2078
# Technology         1813
# Name: Category, dtype: int64

# %%
df['Sub-Category'].value_counts()
# Out:
# Binders        1492
# Paper          1338
# Furnishings     931
# Phones          876
# Storage         832
# Art             785
# Accessories     756
# Chairs          607
# Appliances      459
# Labels          357
# Tables          314
# Envelopes       248
# Bookcases       226
# Fasteners       214
# Supplies        184
# Machines        115
# Copiers          66
# Name: Sub-Category, dtype: int64

# %% [markdown]
# ## Checking for Null Values

# %%
df.isnull().sum()
# Out:
# Row ID            0
# Order ID          0
# Order Date        0
# Ship Date         0
# Ship Mode         0
# Customer ID       0
# Customer Name     0
# Segment           0
# Country           0
# City              0
# State             0
# Postal Code      11
# Region            0
# Product ID        0
# Category          0
# Sub-Category      0
# Product Name      0
# Sales             0
# dtype: int64

# %%
df[df['Postal Code'].isnull()]
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8798    8799  US-2017-150140  06/04/2017  10/04/2017  Standard Class
# 9146    9147  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9147    9148  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9148    9149  US-2017-165505  23/01/2017  27/01/2017  Standard Class
# 9386    9387  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9387    9388  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9388    9389  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9389    9390  US-2018-127292  19/01/2018  23/01/2018  Standard Class
# 9741    9742  CA-2016-117086  08/11/2016  12/11/2016  Standard Class
#
#      Customer ID     Customer Name      Segment        Country        City  \
# ...

# %%
df[df['City'] == 'Burlington']
# Only Burlington city in Vermont State is missing postal code.
# Out:
#       Row ID        Order ID  Order Date   Ship Date       Ship Mode  \
# 683      684  US-2018-168116  04/11/2018  04/11/2018        Same Day
# 684      685  US-2018-168116  04/11/2018  04/11/2018        Same Day
# 1008    1009  US-2018-106705  26/12/2018  01/01/2019  Standard Class
# 1038    1039  CA-2018-121818  20/11/2018  21/11/2018     First Class
# 1039    1040  CA-2018-121818  20/11/2018  21/11/2018     First Class
# 1393    1394  CA-2018-124828  03/07/2018  04/07/2018     First Class
# 2234    2235  CA-2018-104066  05/12/2018  10/12/2018  Standard Class
# 2928    2929  US-2018-120390  19/10/2018  26/10/2018  Standard Class
# 5065    5066  CA-2018-142090  30/11/2018  07/12/2018  Standard Class
# 5066    5067  CA-2018-142090  30/11/2018  07/12/2018  Standard Class
# 5274    5275  CA-2016-162887  07/11/2016  09/11/2016    Second Class
# 8317    8318  CA-2018-130904  11/04/2018  16/04/2018  Standard Class
# 8318    8319  CA-2018-130904  11/04/2018  16/04/2018  Standard Class
# ...

# %%
df['Postal Code'] = df['Postal Code'].fillna(5401)

# %%
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# dtype: int64

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# First, need to convert Order date and Ship Date from object into Date Time

# %%
df.dtypes.head(5)
# Out:
# Row ID         int64
# Order ID      object
# Order Date    object
# Ship Date     object
# Ship Mode     object
# dtype: object

# %%
df['Order Date'] = pd.to_datetime(df['Order Date'], format= '%d/%m/%Y')
df['Ship Date'] = pd.to_datetime(df['Ship Date'], format= '%d/%m/%Y')

# %%
print(df['Order Date'].head(2))
print(df['Ship Date'].head(2))
# Out:
# 0   2017-11-08
# 1   2017-11-08
# Name: Order Date, dtype: datetime64[ns]
# 0   2017-11-11
# 1   2017-11-11
# Name: Ship Date, dtype: datetime64[ns]

# %%
df['ShippingTime'] = df['Ship Date'] - df['Order Date']
df['ShippingTime']
# Out:
# 0      3 days
# 1      3 days
# 2      4 days
# 3      7 days
# 4      7 days
#         ...
# 9795   7 days
# 9796   5 days
# 9797   5 days
# 9798   5 days
# 9799   5 days
# Name: ShippingTime, Length: 9800, dtype: timedelta64[ns]

# %% [markdown]
# ## More Visualizations

# %% [markdown]
# #### Looking at the top customers based on how much they have spent.

# %%
topcust = df.groupby(["Customer Name"]).sum().sort_values("Sales", ascending=False).head(10)
topcust = topcust[["Sales"]].round(2)
topcust.reset_index(inplace=True)

# %%
topcust
# Out:
#         Customer Name     Sales
# 0         Sean Miller  25043.05
# 1        Tamara Chand  19052.22
# 2        Raymond Buch  15117.34
# 3        Tom Ashbrook  14595.62
# 4       Adrian Barton  14473.57
# 5        Ken Lonsdale  14175.23
# 6        Sanjit Chand  14142.33
# 7        Hunter Lopez  12873.30
# 8        Sanjit Engle  12209.44
# 9  Christopher Conant  12129.07

# %%
plt.figure(figsize=(15,12))

xaxis = topcust['Customer Name']
yaxis = topcust['Sales']
ax = sns.barplot(xaxis, yaxis)

plt.title('Top 10 Customers based on Spending')
plt.xticks(rotation=45)
plt.ylabel('Earning', fontsize = 20)
plt.xlabel('Customer', fontsize = 20)


for p in ax.patches:
             ax.annotate("%.2f" % (p.get_height()*100/sum(yaxis))+'%', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=13, color='black', xytext=(0, 20),
                 textcoords='offset points')
        
for p in ax.patches:
             ax.annotate('$'+ str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='black', xytext=(0, -60),
                 textcoords='offset points')

# %% [markdown]
# #### Looking at the top cities based on how much they have spent.

# %%
topcity = df.groupby(["City"]).sum().sort_values("Sales", ascending=False).head(10)
topcity = topcity[["Sales"]].round(2)
topcity.reset_index(inplace=True)

# %%
topcity
# Out:
#             City      Sales
# 0  New York City  252462.55
# 1    Los Angeles  173420.18
# 2        Seattle  116106.32
# 3  San Francisco  109041.12
# 4   Philadelphia  108841.75
# 5        Houston   63956.14
# 6        Chicago   47820.13
# 7      San Diego   47521.03
# 8   Jacksonville   44713.18
# 9        Detroit   42446.94

# %%
plt.figure(figsize=(15,12))

xaxis = topcity['City']
yaxis = topcity['Sales']
ax = sns.barplot(xaxis, yaxis)

plt.title('Top 10 Cities based on Spending')
plt.xticks(rotation=45)
plt.ylabel('Earning', fontsize = 20)
plt.xlabel('City', fontsize = 20)


for p in ax.patches:
             ax.annotate("%.2f" % (p.get_height()*100/sum(yaxis))+'%', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=13, color='black', xytext=(0, 20),
                 textcoords='offset points')
        
for p in ax.patches:
             ax.annotate('$'+ str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='black', xytext=(0, -60),
                 textcoords='offset points')

# %% [markdown]
# #### Looking at the distribution of categories based on how much they make.

# %%
topcat = df.groupby(["Category"]).sum().sort_values("Sales", ascending=False).head(10)
topcat = topcat[["Sales"]].round(2)
topcat.reset_index(inplace=True)

# %%
topcat
# Out:
#           Category      Sales
# 0       Technology  827455.87
# 1        Furniture  728658.58
# 2  Office Supplies  705422.33

# %%
plt.figure(figsize=(10,7))

xaxis = topcat['Category']
yaxis = topcat['Sales']
ax = sns.barplot(xaxis, yaxis)

plt.title('Distribution of Category Earnings', fontsize = 15)
plt.xticks(rotation=45, fontsize=12)
plt.ylabel('Earning', fontsize=12)
plt.xlabel('Category', fontsize=12)


for p in ax.patches:
             ax.annotate("%.2f" % (p.get_height()*100/sum(yaxis))+'%', (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=13, color='black', xytext=(0, 20),
                 textcoords='offset points')
        
for p in ax.patches:
             ax.annotate('$'+ str(p.get_height()), (p.get_x() + p.get_width() / 2., p.get_height()),
                 ha='center', va='center', fontsize=11, color='black', xytext=(0, -60),
                 textcoords='offset points')

# %% [markdown]
# #### Looking at the distribution of products based on how much they make.

# %%
topprod = df.groupby(["Product Name"]).sum().sort_values("Sales", ascending=False).head(10)
topprod = topprod[["Sales"]].round(2)
topprod.reset_index(inplace=True)

# %%
topprod
# Out:
#                                         Product Name     Sales
# 0              Canon imageCLASS 2200 Advanced Copier  61599.82
# 1  Fellowes PB500 Electric Punch Plastic Comb Bin...  27453.38
# 2  Cisco TelePresence System EX90 Videoconferenci...  22638.48
# 3       HON 5400 Series Task Chairs for Big and Tall  21870.58
# 4         GBC DocuBind TL300 Electric Binding System  19823.48
# 5   GBC Ibimaster 500 Manual ProClick Binding System  19024.50
# 6               Hewlett Packard LaserJet 3310 Copier  18839.69
# 7  HP Designjet T520 Inkjet Large Format Printer ...  18374.90
# 8          GBC DocuBind P400 Electric Binding System  17965.07
# 9        High Speed Automatic Electric Letter Opener  17030.31

# %%
plt.figure(figsize=(12,12))
my_circle=plt.Circle( (0,0), 0.7, color='white')

plt.pie(topprod['Sales'], labels=topprod['Product Name'], autopct='%1.1f%%', colors=['red', 'green'])
p=plt.gcf()
p.gca().add_artist(my_circle)
plt.title('Distribution of Category Earnings')
plt.show()
